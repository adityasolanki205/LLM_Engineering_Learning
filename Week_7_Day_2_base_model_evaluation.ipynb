# %% [markdown]
# ## Predict Product Prices
#
# ### Week 7 Day 2
#
# Selecting our model and evaluating the base model against the task.
#
# Keep in mind: our base model has 8 billion params, quantized down to 4 bits
# Compared with GPT-4o at TRILLIONS of params!
#
# # IMPORTANT please read me!!
#
# When you run the pip installs below, you may get an error from pip complaining about an incompatible version of fsspec.
#
# You should ignore that error! The version of fsspec is the right version, needed by HuggingFace.
#
# If you ask ChatGPT, it will encourage you to pip install a more recent version of fsspec. But that would be problematic; HuggingFace will fail to load the dataset later with an obscure error about file systems.
#
# So please run the pip installs as they appear below, and look the other way if you get an error!

# %%
# pip installs - ignore the error message!

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 42.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 35.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 127.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 133.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 33.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 142.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 120.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 1.17.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, set_seed
from peft import LoraConfig, PeftModel
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Tokenizers

LLAMA_3_1 = "meta-llama/Meta-Llama-3.1-8B"
QWEN_2_5 = "Qwen/Qwen2.5-7B"
GEMMA_2 = "google/gemma-2-9b"
PHI_3 = "microsoft/Phi-3-medium-4k-instruct"

# Constants

BASE_MODEL = LLAMA_3_1
HF_USER = "aditya-solanki"
DATASET_NAME = f"{HF_USER}/lite-data"
MAX_SEQUENCE_LENGTH = 182
QUANT_4_BIT = True

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %matplotlib inline

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
def investigate_tokenizer(model_name):
  print("Investigating tokenizer for", model_name)
  tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
  for number in [0, 1, 10, 100, 999, 1000]:
    tokens = tokenizer.encode(str(number), add_special_tokens=False)
    print(f"The tokens for {number}: {tokens}")

# %%
# Now we will try this with each model: LLAMA_3_1, QWEN_2_5, GEMMA_2, PHI_3

investigate_tokenizer(GEMMA_2)
# Out:
# Investigating tokenizer for google/gemma-2-9b
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# The tokens for 0: [235276]
# The tokens for 1: [235274]
# The tokens for 10: [235274, 235276]
# The tokens for 100: [235274, 235276, 235276]
# The tokens for 999: [235315, 235315, 235315]
# The tokens for 1000: [235274, 235276, 235276, 235276]

# %% [markdown]
# # Load our data
#
# We uploaded it to Hugging Face, so it's easy to retrieve it now

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/39.5M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/2.17M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/90000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': 'How much does this cost to the nearest dollar?\n\nWaterdrop FXRC Refrigerator Water Filter, Replacement for GE® MXRC, FXRC, FXRT, HXRC, 9905, & 1E1013 (Package May Vary)\nReplacement for filter models GE FXRC, MXRC, 9905, FXRT, HXRT. This Waterdrop refrigerator water filter replacement for MXRC, despite its affordable price, offers the best - a mix of prior filtration performance and great tasting water. Thanks to the Sri Lankan superior coconut shell carbon block, this filter is effective against various contaminants. Perfect fit You can now worry less about water leakages due to unfit or loose replacement refrigerator filters. This Waterdrop refrigerator filter replacement is made from an advanced industrial automation system and a precision measurement technology that ensures that you get the\n\nPrice is $',
#  'price': 34.99}

# %% [markdown]
# # Prepare our Base Llama Model for evaluation
#
# Load our base model with 4 bit quantization and try out 1 example

# %%
## pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Memory footprint: {base_model.get_memory_footprint() / 1e9:.1f} GB")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Memory footprint: 5.6 GB

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','').replace('$','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $999 blah blah so cheap")
# Out:
# 999.0

# %%
def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = base_model.generate(inputs, max_new_tokens=4, attention_mask=attention_mask, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
model_predict(test[0]['text'])
# Out:
# 19.99

# %% [markdown]
# # Evaluation!
#
# Trying out our base Llama 3.1 model against the Test dataset

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(model_predict, test)
# Out:
# 1: Guess: $19.99 Truth: $34.99 Error: $15.00 SLE: 0.29 Item: Waterdrop FXRC Refri...
# 2: Guess: $1.50 Truth: $8.54 Error: $7.04 SLE: 1.79 Item: IF YOU CARE No. 2 Co...
# 3: Guess: $25.00 Truth: $39.19 Error: $14.19 SLE: 0.19 Item: Glory 1/4 Solid Wood...
# 4: Guess: $299.00 Truth: $713.70 Error: $414.70 SLE: 0.75 Item: Fire Magic 4.0 Cu. F...
# 5: Guess: $7.99 Truth: $5.99 Error: $2.00 SLE: 0.06 Item: Reusable K Cups Coff...
# 6: Guess: $25.00 Truth: $29.95 Error: $4.95 SLE: 0.03 Item: Tyler TWM302 Dual Fr...
# 7: Guess: $7.50 Truth: $20.98 Error: $13.48 SLE: 0.90 Item: Remo Clear Diplomat ...
# 8: Guess: $25.00 Truth: $30.99 Error: $5.99 SLE: 0.04 Item: Dragonfly Diashwaher...
# 9: Guess: $7.50 Truth: $12.99 Error: $5.49 SLE: 0.25 Item: Strings Nickel Plate...
# 37: Guess: $7.99 Truth: $18.99 Error: $11.00 SLE: 0.64 Item: Kmise Electric Guita...
# 38: Guess: $7.50 Truth: $19.95 Error: $12.45 SLE: 0.81 Item: Gibraltar SC-BGC Bas...
# 39: Guess: $25.00 Truth: $96.59 Error: $71.59 SLE: 1.75 Item: Compatible Dryer Hea...
# 40: Guess: $7.99 Truth: $24.97 Error: $16.98 SLE: 1.13 Item: Cowbright Quilted St...
# 41: Guess: $7.50 Truth: $11.49 Error: $3.99 SLE: 0.15 Item: DR Strings HI-DEF NE...
# 42: Guess: $25.00 Truth: $539.95 Error: $514.95 SLE: 9.21 Item: Zildjian K Mastersou...
# 43: Guess: $7.99 Truth: $7.80 Error: $0.19 SLE: 0.00 Item: 4 Pack Dishwasher Sp...
# 44: Guess: $19.99 Truth: $69.11 Error: $49.12 SLE: 1.45 Item: TONOR Dual Lavalier ...
# 45: Guess: $19.99 Truth: $19.99 Error: $0.00 SLE: 0.00 Item: WiFi Temperature Hum...
# 46: Guess: $7.99 Truth: $10.27 Error: $2.28 SLE: 0.05 Item: Camco 00473 8 Univer...
# 47: Guess: $299.00 Truth: $265.36 Error: $33.64 SLE: 0.01 Item: Galanz Cooktop, 4 Tr...
# 48: Guess: $7.99 Truth: $10.69 Error: $2.70 SLE: 0.07 Item: 2Pcs Yootones Piezo ...
# 49: Guess: $25.00 Truth: $9.90 Error: $15.10 SLE: 0.76 Item: Guitar Capo with Tun...
# 50: Guess: $7.50 Truth: $10.33 Error: $2.83 SLE: 0.08 Item: Piano Keytop Heads S...
# 51: Guess: $7.50 Truth: $9.86 Error: $2.36 SLE: 0.06 Item: Deflecto Magnetic Ve...
# 52: Guess: $7.00 Truth: $6.06 Error: $0.94 SLE: 0.02 Item: Durpower Phonograph ...
# 53: Guess: $19.99 Truth: $29.97 Error: $9.98 SLE: 0.15 Item: YLL Car Karaoke Micr...
# 54: Guess: $7.99 Truth: $6.99 Error: $1.00 SLE: 0.01 Item: Washer Pulsator Wash...
# 55: Guess: $1,800.00 Truth: $98.50 Error: $1,701.50 SLE: 8.39 Item: Pirastro Evah Pirazz...
# 56: Guess: $7.99 Truth: $5.99 Error: $2.00 SLE: 0.06 Item: Beyond Gourmet Paper...
# 57: Guess: $25.99 Truth: $85.00 Error: $59.01 SLE: 1.34 Item: Chims DJ Party Light...
# 58: Guess: $299.00 Truth: $299.95 Error: $0.95 SLE: 0.00 Item: Odyssey Fzgspiddjsx ...
# 59: Guess: $89.99 Truth: $139.99 Error: $50.00 SLE: 0.19 Item: HyperX QuadCast S – ...
# 60: Guess: $299.00 Truth: $249.99 Error: $49.01 SLE: 0.03 Item: PreSonus Studio 24c ...
# 61: Guess: $25.00 Truth: $49.99 Error: $24.99 SLE: 0.45 Item: Mr. Dj SS350R Univer...
# 62: Guess: $25.00 Truth: $23.98 Error: $1.02 SLE: 0.00 Item: DharmaObjects® Gorge...
# 225: Guess: $89.00 Truth: $159.99 Error: $70.99 SLE: 0.34 Item: Dream Cymbals BCR14 ...
# 226: Guess: $7.99 Truth: $19.99 Error: $12.00 SLE: 0.72 Item: 24 Pieces 8 Keys Min...
# 227: Guess: $7.99 Truth: $14.99 Error: $7.00 SLE: 0.33 Item: 3 Pieces 21 to 24 In...
# 228: Guess: $25.00 Truth: $14.99 Error: $10.01 SLE: 0.24 Item: LTGEM EVA Hard Stora...
# 229: Guess: $7.99 Truth: $18.98 Error: $10.99 SLE: 0.64 Item: GELRHONR Dual XLR 3P...
# 230: Guess: $299.00 Truth: $422.06 Error: $123.06 SLE: 0.12 Item: Allen & Heath XONE 2...
# 231: Guess: $7.99 Truth: $7.30 Error: $0.69 SLE: 0.01 Item: Lovermusic Dia Round...
# 232: Guess: $7.50 Truth: $13.82 Error: $6.32 SLE: 0.31 Item: Pickboy Edge, Sharp ...
# 233: Guess: $19.99 Truth: $32.99 Error: $13.00 SLE: 0.23 Item: Yibuy 9# Silver Jazz...
# 234: Guess: $7.99 Truth: $9.99 Error: $2.00 SLE: 0.04 Item: Dunlop Tortex The We...
# 235: Guess: $1.50 Truth: $8.99 Error: $7.49 SLE: 1.92 Item: Transgender Trans Pr...
# 236: Guess: $7.99 Truth: $16.97 Error: $8.98 SLE: 0.48 Item: AMI PARTS TB123A Was...
# 237: Guess: $7.50 Truth: $4.99 Error: $2.51 SLE: 0.12 Item: Blisstime Bone Guita...
# 238: Guess: $299.00 Truth: $314.90 Error: $15.90 SLE: 0.00 Item: Rockville (2) 15 800...
# 239: Guess: $25.99 Truth: $27.86 Error: $1.87 SLE: 0.00 Item: LOLUNUT Snare Drum S...
# 240: Guess: $25.00 Truth: $89.99 Error: $64.99 SLE: 1.57 Item: Allen & Heath Dust C...
# 241: Guess: $7.99 Truth: $7.35 Error: $0.64 SLE: 0.01 Item: MAXCHEER Guitar Inpu...
# 242: Guess: $25.99 Truth: $22.99 Error: $3.00 SLE: 0.01 Item: Bass Traps 16 Pack 1...
# 243: Guess: $7.99 Truth: $12.56 Error: $4.57 SLE: 0.17 Item: Protec Neoprene Tuba...
# 244: Guess: $25.00 Truth: $11.85 Error: $13.15 SLE: 0.50 Item: Clothes Dryer Belt R...
# 245: Guess: $25.00 Truth: $34.95 Error: $9.95 SLE: 0.10 Item: Rockville 2.4GHZ Wir...
# 246: Guess: $19.99 Truth: $58.99 Error: $39.00 SLE: 1.10 Item: Upstart Battery 6-Pa...
# 247: Guess: $25.00 Truth: $25.50 Error: $0.50 SLE: 0.00 Item: Whirlpool Original G...
# 248: Guess: $1.00 Truth: $13.00 Error: $12.00 SLE: 3.79 Item: Runyon 6133 Saxophon...
# 249: Guess: $1,999.00 Truth: $772.92 Error: $1,226.08 SLE: 0.90 Item: StewMac Guitar Buffi...
# 250: Guess: $25.00 Truth: $46.04 Error: $21.04 SLE: 0.35 Item: Frigidaire Frigidare...
